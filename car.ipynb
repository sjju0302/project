# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
auto = pd.read_csv("auto-mpg.csv")

# %%
 auto = auto.drop(columns= [ "car_name", "origin", "horsepower"],axis= 1)

# %%
auto
# Out:
#       mpg  cylinders  displacement  weight  acceleration  model_year
# 0    18.0          8         307.0    3504          12.0          70
# 1    15.0          8         350.0    3693          11.5          70
# 2    18.0          8         318.0    3436          11.0          70
# 3    16.0          8         304.0    3433          12.0          70
# 4    17.0          8         302.0    3449          10.5          70
# ..    ...        ...           ...     ...           ...         ...
# 393  27.0          4         140.0    2790          15.6          82
# 394  44.0          4          97.0    2130          24.6          82
# 395  32.0          4         135.0    2295          11.6          82
# 396  28.0          4         120.0    2625          18.6          82
# 397  31.0          4         119.0    2720          19.4          82
#
# [398 rows x 6 columns]

# %%
plt.boxplot(auto.mpg)
plt.xlabel("mpg")
# Out:
# Text(0.5, 0, 'mpg')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6)) 

auto.boxplot(column=list(auto.select_dtypes(include=['number']).columns))
plt.xticks(rotation=45)  

plt.tight_layout()  # 레이아웃 조정
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
X = auto.drop("mpg", axis = 1)

# %%
y= auto.mpg

# %%
reg = LinearRegression()

# %%
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 reg.score(reg.predict(X),y)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:759, in RegressorMixin.score(self, X, y, sample_weight)
#     717 """Return the coefficient of determination of the prediction.
#     718
#     719 The coefficient of determination :math:`R^2` is defined as
#    (...)
#     754 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     755 """
#     757 from .metrics import r2_score
# --> 759 y_pred = self.predict(X)
#     760 return r2_score(y, y_pred, sample_weight=sample_weight)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:386, in LinearModel.predict(self, X)
# ...

# %%
reg.coef_
# Out:
# array([-0.25858516,  0.00726771, -0.00692571,  0.08034746,  0.75530084])

# %%
cylinders = int(input("cylinders:"))
displacement =int(input("displacement:"))
weight = int(input("weight:"))
acceleration = int(input("acceleration:"))
model_year = int(input("model_year:"))
mpg = reg.predict([[cylinders,displacement,weight,acceleration,model_year]])
print(f"mpg:{mpg} ")
# Out:
# cylinders:8
# displacement:350
# weight:3200
# acceleration:22
# model_year:99
# mpg:[40.28549435]
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, classification_report
from sklearn.linear_model import LogisticRegression

reg = LinearRegression().fit(X,y)

# k-fold 교차검증을 통한 예측
y_pred = cross_val_predict(reg, X, y, cv=10)  # 5-fold 교차검증 예시

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score, accuracy_score
print(mean_absolute_error(y, y_pred), 
mean_squared_error(y,y_pred), 
r2_score(y,y_pred))
# Out:
# 2.843658015934886 13.431146980413871 0.7795864400797785

# %%
import seaborn as sns
sns.heatmap(auto.corr(), annot=True)
# Out:
# <Axes: >

# %%
accuracy = accuracy_score(Y, y_pred)
print("정확도:", accuracy)
